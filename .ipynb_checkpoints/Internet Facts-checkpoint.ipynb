# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#------------------------------
#Social Media Usage by Age
df = pd.read_excel("Dataset/internet_social_media_facts/social_media_fact_sheet.xlsx", sheet_name=2, skiprows=1)
#pd.options.display.float_format = '{:.2%}'.format
df = pd.DataFrame(df)
df['White'].fillna(0, inplace=True)
df['Black'].fillna(0, inplace=True)
df['Hispanic'].fillna(0, inplace=True)

df = df.rename(columns={'Unnamed: 0':'date'})
df = df.set_index('date')
df.head()
# Out:
#             White  Black  Hispanic
# date
# 2005-03-21   0.05   0.04       0.0
# 2005-12-08   0.08   0.07       0.0
# 2006-08-31   0.09   0.11       0.0
# 2008-05-11   0.19   0.21       0.0
# 2008-08-10   0.21   0.32       0.0

# %%
ax = df.plot(y=["White", "Black", "Hispanic"], kind='line', color=['r','b','g'])
type(ax)
vals = ax.get_yticks()
ax.set_yticklabels(['{:.2%}'.format(x) for x in vals])
plt.title("% of U.S. adults who use at least one social media site, by race")
plt.legend(loc='best')
plt.savefig('sm_use_by_race.png')
plt.show();

# %%
#------------------------------
#Social Media Usage by Education Level
df_edu = pd.read_excel("Dataset/internet_social_media_facts/social_media_fact_sheet.xlsx", sheet_name=5, skiprows=1)
df_edu = pd.DataFrame(df_edu)
df_edu = df_edu.rename(columns = {'Unnamed: 0':'date'})
df_edu = df_edu.set_index('date')
df_edu.head()
# Out:
#             High school or less  Some college  College graduate
# date
# 2005-03-21                 0.03          0.05              0.10
# 2005-12-08                 0.05          0.10              0.13
# 2006-08-31                 0.09          0.17              0.09
# 2008-05-11                 0.18          0.29              0.21
# 2008-08-10                 0.22          0.32              0.29

# %%
ax = df_edu.plot(y=["High school or less", "Some college", "College graduate"], kind='line', color=['r','b','g'])
type(ax)
vals = ax.get_yticks()
ax.set_yticklabels(['{:.2%}'.format(x) for x in vals])

plt.title("% of U.S. adults who use at least one social media site, by education level")
plt.legend(loc='best')
plt.savefig('sm_use_by_edu.png')
plt.show();

# %%
#------------------------------
#Social Media Usage by Income Level
df_income = pd.read_excel("Dataset/internet_social_media_facts/social_media_fact_sheet.xlsx", sheet_name=4, skiprows=1)
df_income = df_income.rename(columns={"Unnamed: 0":"date"})
df_income = df_income.set_index('date')
df_income.head()
# Out:
#             Less than $30,000  $30,000-$49,999  $50,000-$74,999  $75,000+
# date
# 2005-03-21               0.03             0.06             0.08      0.07
# 2005-12-08               0.05             0.09             0.09      0.15
# 2006-08-31               0.08             0.16             0.09      0.10
# 2008-05-11               0.23             0.23             0.19      0.25
# 2008-08-10               0.27             0.28             0.28      0.30

# %%
ax = df_income.plot(y=["Less than $30,000", "$30,000-$49,999", "$50,000-$74,999", "$75,000+"], kind='line', color=['r','b','g','aqua'])
type(ax)
vals = ax.get_yticks()
ax.set_yticklabels(['{:.2%}'.format(x) for x in vals])
plt.title("% of U.S. adults who use at least one social media site, by income")
plt.legend(loc='best')
plt.savefig('sm_use_by_income.png')
plt.show();

# %%
#------------------------------
#Social Media Usage by Platform
df_summary = pd.read_excel("Dataset/internet_social_media_facts/social_media_fact_sheet.xlsx", sheet_name=9, skiprows=3)
#df_summary = df_summary.rename(columns={"Unnamed: 0":"date"})
#df_summary = df_summary.set_index('date')
pd.options.display.float_format = '{:.2%}'.format
df_summary
# Out:
#              Unnamed: 0  Twitter  Pinterest  Snapchat
# 0                 Total   22.00%     28.00%    24.00%
# 1                   Men   24.00%     15.00%    24.00%
# 2                 Women   21.00%     42.00%    24.00%
# 3            Ages 18-29   38.00%     34.00%    62.00%
# 4                 30-49   26.00%     35.00%    25.00%
# 5                 50-64   17.00%     27.00%     9.00%
# 6                   65+    7.00%     15.00%     3.00%
# 7                 White   21.00%     33.00%    22.00%
# 8                 Black   24.00%     27.00%    28.00%
# 9              Hispanic   25.00%     22.00%    29.00%
# 10  High school or less   13.00%     19.00%    22.00%
# 11         Some college   24.00%     32.00%    29.00%
# 12     College graduate   32.00%     38.00%    20.00%
# 13                Urban   26.00%     30.00%    29.00%
# 14             Suburban   22.00%     30.00%    20.00%
# 15                Rural   13.00%     26.00%    20.00%
