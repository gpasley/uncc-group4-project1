# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
crime_df = pd.DataFrame({"Year": [2011, 2012, 2013, 2014], "Human Trafficking": ["N/A", "N/A", 6, 47], "Kidnapping/Abduction": [13470, 13870, 13898, 13744],
                        "Embezzlement": [17000, 17364, 18241, 18885], "Extortion": [1217, 1180, 1448, 1684], 
                        "Fraud Offenses": [245301, 261718, 270106, 294160], "Larceny/Theft": [1683877, 1722672, 1733727, 1662432],
                        "Pornography/Obscene Material": [5791, 6026, 7292, 8516]})
crime_df
# Out:
#    Year Human Trafficking  Kidnapping/Abduction  Embezzlement  Extortion  \
# 0  2011               N/A                 13470         17000       1217
# 1  2012               N/A                 13870         17364       1180
# 2  2013                 6                 13898         18241       1448
# 3  2014                47                 13744         18885       1684
#
#    Fraud Offenses  Larceny/Theft  Pornography/Obscene Material
# 0          245301        1683877                          5791
# 1          261718        1722672                          6026
# 2          270106        1733727                          7292
# 3          294160        1662432                          8516

# %%
year = [2011, 2012, 2013, 2014]
human_trafficking = [0, 0, 6, 47]
kidnapping = [13470, 13870, 13898, 13744]
embezzlement = [17000, 17364, 18241, 18885]
extortion = [1217, 1180, 1448, 1684]
fraud = [245301, 261718, 270106, 294160]
larceny = [1683877, 1722672, 1733727, 1662432]
obscene_material = [5791, 6026, 7292, 8516]

# %%
x_axis = np.arange(len(kidnapping))
plt.bar(x_axis, kidnapping, color="skyblue", align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["2011", "2012", "2013", "2014"])
plt.xlabel("Year")
plt.ylabel("Number of Reported Incidents(Per Year)")
plt.title("Reported Kidnapping Incidents")
plt.savefig("../Project/Kidnapping_Incidents.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
