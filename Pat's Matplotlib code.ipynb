# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Obesity = {"Time":["1971-1974","1976-1980","1988-1994","1999-2000","2001-2002","2003-2004","2005-2006","2007-2008","2009-2010","2011-2012","2013-2014"],"Age":["12-19","12-19","12-19","12-19","12-19","12-19","12-19","12-19","12-19","12-19","12-19"],"Gender":["M/F","M/F","M/F","M/F","M/F","M/F","M/F","M/F","M/F","M/F","M/F"],"Obesity_Percent":[6.1,5,10.5,14.8,16.7,17.4,17.8,18.1,18.4,20.5,20.6]}

Obesity_df = pd.DataFrame.from_dict(Obesity)
Obesity_df
# Out:
#          Time    Age Gender  Obesity_Percent
# 0   1971-1974  12-19    M/F              6.1
# 1   1976-1980  12-19    M/F              5.0
# 2   1988-1994  12-19    M/F             10.5
# 3   1999-2000  12-19    M/F             14.8
# 4   2001-2002  12-19    M/F             16.7
# 5   2003-2004  12-19    M/F             17.4
# 6   2005-2006  12-19    M/F             17.8
# 7   2007-2008  12-19    M/F             18.1
# 8   2009-2010  12-19    M/F             18.4
# 9   2011-2012  12-19    M/F             20.5
# 10  2013-2014  12-19    M/F             20.6

# %%
Obesity_list = Obesity_df['Obesity_Percent'].tolist()
Obesity_list
# Out:
# [6.1, 5.0, 10.5, 14.8, 16.7, 17.4, 17.8, 18.1, 18.4, 20.5, 20.6]

# %%
time_list = Obesity_df['Time'].tolist()
time_list
# Out:
# ['1971-1974',
#  '1976-1980',
#  '1988-1994',
#  '1999-2000',
#  '2001-2002',
#  '2003-2004',
#  '2005-2006',
#  '2007-2008',
#  '2009-2010',
#  '2011-2012',
#  '2013-2014']

# %%
Obesity_Bar = plt.subplots(figsize=(13,5))
plt.bar(time_list, Obesity_list, color="b", align="center", width=0.5)
plt.title("Obesity Rates in the U.S. for Kids Ages 12-19")
plt.ylabel("Percentage of Obese Children (%)")
              
Obesity_Bar
# Out:
# (<Figure size 936x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23564b3e048>)

# %%
internet = pd.read_csv("C:\\Users\\User\\Internet_Usage.csv")
internet
# Out:
#     % of U.S Adults who use the internet, by education level  \
# 0                                                 NaN
# 1                                              2000.0
# 2                                              2001.0
# 3                                              2002.0
# 4                                              2003.0
# 5                                              2004.0
# 6                                              2005.0
# 7                                              2006.0
# 8                                              2007.0
# 9                                              2008.0
# 10                                             2009.0
# 11                                             2010.0
# 12                                             2011.0
# 13                                             2012.0
# 14                                             2013.0
# 15                                             2014.0
# ...

# %%
df = internet.rename(columns={'Unnamed: 1':'Elementary School','Unnamed: 2':'Middle School','Unnamed: 3':'High School','Unnamed: 4':'College'})
df
# Out:
#     % of U.S Adults who use the internet, by education level  \
# 0                                                 NaN
# 1                                              2000.0
# 2                                              2001.0
# 3                                              2002.0
# 4                                              2003.0
# 5                                              2004.0
# 6                                              2005.0
# 7                                              2006.0
# 8                                              2007.0
# 9                                              2008.0
# 10                                             2009.0
# 11                                             2010.0
# 12                                             2011.0
# 13                                             2012.0
# 14                                             2013.0
# 15                                             2014.0
# ...

# %%
df2 = df.dropna()
df2
# Out:
#     % of U.S Adults who use the internet, by education level  \
# 1                                              2000.0
# 2                                              2001.0
# 3                                              2002.0
# 4                                              2003.0
# 5                                              2004.0
# 6                                              2005.0
# 7                                              2006.0
# 8                                              2007.0
# 9                                              2008.0
# 10                                             2009.0
# 11                                             2010.0
# 12                                             2011.0
# 13                                             2012.0
# 14                                             2013.0
# 15                                             2014.0
# 16                                             2015.0
# ...

# %%
df3 = df2.rename(columns={'% of U.S Adults who use the internet, by education level':'Year'})
df3
# Out:
#       Year Elementary School Middle School High School College
# 1   2000.0               19%           40%         67%     78%
# 2   2001.0               21%           43%         68%     81%
# 3   2002.0               24%           48%         73%     83%
# 4   2003.0               25%           51%         75%     85%
# 5   2004.0               27%           53%         76%     86%
# 6   2005.0               32%           58%         80%     89%
# 7   2006.0               37%           61%         83%     91%
# 8   2007.0               40%           65%         85%     92%
# 9   2008.0               38%           65%         86%     93%
# 10  2009.0               40%           68%         87%     94%
# 11  2010.0               41%           68%         87%     93%
# 12  2011.0               43%           72%         89%     94%
# 13  2012.0               52%           75%         91%     96%
# 14  2013.0               54%           75%         92%     96%
# ...

# %%
x = ['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
x
# Out:
# ['2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019']

# %%
y1 = ['40%',
 '41%',
 '43%',
 '52%',
 '54%',
 '55%',
 '62%',
 '68%',
 '65%',
 '71%']
y1
# Out:
# ['40%', '41%', '43%', '52%', '54%', '55%', '62%', '68%', '65%', '71%']

# %%
y2 = [ '68%',
 '68%',
 '72%',
 '75%',
 '75%',
 '76%',
 '78%',
 '81%',
 '84%',
 '84%']
y2
# Out:
# ['68%', '68%', '72%', '75%', '75%', '76%', '78%', '81%', '84%', '84%']

# %%
y3 =  ['87%',
 '87%',
 '89%',
 '91%',
 '92%',
 '91%',
 '92%',
 '94%',
 '93%',
 '95%']
y3
# Out:
# ['87%', '87%', '89%', '91%', '92%', '91%', '92%', '94%', '93%', '95%']

# %%
y4 =  ['94%',
 '93%',
 '94%',
 '96%',
 '96%',
 '96%',
 '96%',
 '98%',
 '97%',
 '98%']
y4
# Out:
# ['94%', '93%', '94%', '96%', '96%', '96%', '96%', '98%', '97%', '98%']

# %%
Elementary = plt.subplots(figsize=(20,5))

plt.bar(x, y1, color="b", align="center", width=0.5)
plt.title("Percent of Internet Use - Elementary School")
Elementary
# Out:
# (<Figure size 1440x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23567d76e10>)

# %%
Middle = plt.subplots(figsize=(20,5))
plt.bar(x, y2, color="r", align="center", width=0.5)
plt.title("Percent of Internet Use - Middle School")
Middle
# Out:
# (<Figure size 1440x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x235661fa828>)

# %%
High = plt.subplots(figsize=(20,5))
plt.bar(x, y3, color="orange", align="center", width=0.5)
plt.title("Percent of Internet Use - High School")
High
# Out:
# (<Figure size 1440x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2356817a128>)

# %%
College = plt.subplots(figsize=(20,5))
plt.bar(x, y4, color="y", align="center", width=0.5)
plt.title("Percent of Internet Use - College")
College
# Out:
# (<Figure size 1440x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23567f97470>)
